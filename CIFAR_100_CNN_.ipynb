# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'itba-cifar-100-2024-q-1:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F77584%2F8490010%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240624%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240624T154929Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,keras-cv:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F3015042%2F5185697%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240624%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240624T154929Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading itba-cifar-100-2024-q-1, 168426762 bytes compressed
# [==================================================] 168426762 bytes downloaded
# Downloaded and uncompressed: itba-cifar-100-2024-q-1
# Downloading keras-cv, 591800 bytes compressed
# [==================================================] 591800 bytes downloaded
# Downloaded and uncompressed: keras-cv
# Data source import complete.

# %% [markdown]
# #Inicialización y EDA

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/keras-cv/keras_cv-0.4.2-py3-none-any.whl
# /kaggle/input/itba-cifar-100-2024-q-1/x_test.npy
# /kaggle/input/itba-cifar-100-2024-q-1/x_train.npy
# /kaggle/input/itba-cifar-100-2024-q-1/y_train_coarse.npy
# /kaggle/input/itba-cifar-100-2024-q-1/y_train_fine.npy
# /kaggle/input/itba-cifar-100-2024-q-1/coarse_label_names.pck
# /kaggle/input/itba-cifar-100-2024-q-1/fine_label_names.pck

# %%
x_train = np.load("/kaggle/input/itba-cifar-100-2024-q-1/x_train.npy")/255.
x_test = np.load("/kaggle/input/itba-cifar-100-2024-q-1/x_test.npy")/255.
y_train_coarse = np.load("/kaggle/input/itba-cifar-100-2024-q-1/y_train_coarse.npy")
y_train_fine = np.load("/kaggle/input/itba-cifar-100-2024-q-1/y_train_fine.npy")
print(y_train_coarse)
print(y_train_fine)
# Out:
# [11 15  4 ...  8  7  1]
# [19 29  0 ...  3  7 73]

# %%
import pickle
with open("/kaggle/input/itba-cifar-100-2024-q-1/fine_label_names.pck", "rb") as f:
    labels_fine = pickle.load(f)
with open("/kaggle/input/itba-cifar-100-2024-q-1/coarse_label_names.pck", "rb") as f:
    labels_coarse = pickle.load(f)

# %%
from matplotlib import pyplot as plt
#%load_ext tensorboard

# %%
plt.figure(figsize=(10, 10))
cant = 7
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train[i ])
    plt.title([labels_fine[y_train_fine[i]]])
    plt.axis('off')

plt.show()
plt.figure(figsize=(10, 10))

for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train[i +cant ])
    plt.title([labels_fine[y_train_fine[i+ cant]]])
    plt.axis('off')

# %% [markdown]
# ##Cross validation

# %%
from sklearn.model_selection import train_test_split
X_train, X_train_cv, y_train, y_train_cv = train_test_split(np.load("/kaggle/input/itba-cifar-100-2024-q-1/x_train.npy")/255.,
                                                    y_train_fine, test_size=0.2, random_state=42)

# %%
print(len(X_train))
print(len(X_train_cv))
print(len(y_train))
print(len(y_train_cv))
# Out:
# 40000
# 10000
# 40000
# 10000

# %% [markdown]
# #Data Augmentation

# %% [markdown]
# Se realizó un data augmentation tomando un parte del dataset (si se toman todas las imágenes necesitamos mucho recursos de computación y tiempo). En este caso se tomaron 5000 imágenes y se les aplicó RandomCutOut.
#
# Se intentó también cambiar otra cantidad de impagenes con otros métodos, pero no se generaron muchos cambios en la performance de la red.

# %%
pip install keras-cv-nightly
# Out:
# Collecting keras-cv-nightly
#   Downloading keras_cv_nightly-0.10.0.dev2024062403-py3-none-any.whl (650 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.9/650.9 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv-nightly) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv-nightly) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv-nightly) (2024.5.15)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv-nightly) (4.9.6)
# Collecting keras-core (from keras-cv-nightly)
#   Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 65.0 MB/s eta 0:00:00
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv-nightly) (0.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv-nightly) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv-nightly) (4.66.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv-nightly) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv-nightly) (13.7.1)
# Collecting namex (from keras-core->keras-cv-nightly)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv-nightly) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv-nightly) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (3.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (14.0.2)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (2.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (1.14.1)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (0.5.1)
# Requirement already satisfied: etils[enp,epath,epy,etree]>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv-nightly) (1.7.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras-cv-nightly) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras-cv-nightly) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras-cv-nightly) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras-cv-nightly) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv-nightly) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv-nightly) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv-nightly) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv-nightly) (2024.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv-nightly) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv-nightly) (2.16.1)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv-nightly) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv-nightly) (0.1.2)
# Installing collected packages: namex, keras-core, keras-cv-nightly
# Successfully installed keras-core-0.1.7 keras-cv-nightly-0.10.0.dev2024062403 namex-0.0.8

# %%
import keras_cv
# Out:
# Using TensorFlow backend

# %%
random_cutout = keras_cv.layers.RandomCutout(0.5,0.5)
x_train_cutout = random_cutout(X_train[:5000])
y_train_cuout = y_train[:5000]

plt.figure(figsize=(10, 10))
cant = 7
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_cutout[i ])
    plt.title([labels_fine[y_train_cuout[i]]])
    plt.axis('off')

plt.show()
plt.figure(figsize=(10, 10))

for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_cutout[i +cant ])
    plt.title([labels_fine[y_train_cuout[i+ cant]]])
    plt.axis('off')
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7ecbf0634c10>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_loop.py", line 487, in while_loop
#     while cond(*loop_vars):  File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_loop.py", line 479, in <lambda>
#     body = lambda i, lv: (i + 1, orig_body(*lv))  File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/map_fn.py", line 495, in compute
#     return (i + 1, tas)  File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/map_fn.py", line 492, in <listcomp>
#     tas = [  File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/tf_should_use.py", line 288, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================

# %%
grid_mask = keras_cv.layers.GridMask(seed=22)
x_train_grid_mask = grid_mask(X_train[:100])
y_train_grid_mask = y_train[500:1000]
plt.figure(figsize=(10, 10))
cant = 7
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_grid_mask[i])
    plt.title([labels_fine[y_train_grid_mask[i]]])
    plt.axis('off')

plt.show()
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_grid_mask[i +cant  ])
    plt.title([labels_fine[y_train_grid_mask[i+ cant]]])
    plt.axis('off')

# %%
channel_shuffle = keras_cv.layers.ChannelShuffle(seed=22)
x_train_channel_shuffle = channel_shuffle(X_train[1000:1500])
y_train_channel_shuffle = y_train[1000:1500]
plt.figure(figsize=(10, 10))
cant = 7
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_channel_shuffle[i])
    plt.title([labels_fine[y_train_channel_shuffle[i]]])
    plt.axis('off')

plt.show()
for i in range(cant):
    plt.subplot(1, cant, i + 1)
    plt.imshow(x_train_channel_shuffle[i +cant  ])
    plt.title([labels_fine[y_train_channel_shuffle[i+ cant]]])
    plt.axis('off')

# %%
import numpy as np
X_train_final = np.concatenate([X_train,  x_train_cutout, ])
Y_train_final = np.concatenate([ y_train, y_train_cuout, ])
print(len(X_train_final))
# Out:
# 45000

# %% [markdown]
# #Modelo de la red CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Flatten, Conv2D, MaxPooling2D,Activation, SpatialDropout2D, SpatialDropout1D
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.initializers import GlorotNormal, GlorotUniform, RandomNormal, Constant
from tensorflow.keras.optimizers.schedules import InverseTimeDecay

# %%
#Se requiere extender el dataset, se utiliza un generator donde se rotan las imagnes y se obtiene
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=24,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.4
)
datagen.fit(X_train_final)

# %%
#X_train_flip.shape
#plt.figure(figsize=(1,1))
#plt.imshow(x_train[50000])

# %%
model = Sequential()
#Kernel initialiazer
initializer = GlorotUniform()
#First convolution
model.add(Conv2D(128, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
model.add(MaxPooling2D((2, 2)))


#Second convolution
model.add(Conv2D(256, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
# model.add(Dropout(0.2)) #Agregado
model.add(Conv2D(256, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
model.add(BatchNormalization())#Agregado
model.add(MaxPooling2D((2, 2)))


#Third convolution
model.add(Conv2D(512, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
#model.add(Dropout(0.2)) #Agregado
model.add(Conv2D(512, kernel_size= (3, 3) , input_shape=(32,32,3), activation = 'swish', padding= 'same'))
model.add(BatchNormalization())#Agregado
model.add(MaxPooling2D((2, 2)))


model.add(Flatten(input_shape=(32,32,3)))

#First layer
model.add(Dense(1024, activation="swish", kernel_initializer = initializer, kernel_constraint=MaxNorm(4)))
model.add(Dropout(0.2))
#model.add(BatchNormalization())


#second layer
model.add(Dense(512, activation="swish", kernel_initializer = initializer))
#model.add(Dropout(0.25))
model.add(BatchNormalization())

#thrid layer
model.add(Dense(256, activation="swish", kernel_initializer = initializer, kernel_constraint  =MaxNorm(4)))
model.add(Dropout(0.2))
#model.add(BatchNormalization())

#fourth layer
model.add(Dense(100, activation="softmax",kernel_initializer = initializer))

model.compile(loss="sparse_categorical_crossentropy", metrics = ["accuracy"], optimizer = Adam(learning_rate=0.001))

# %%
# lr_schedule =InverseTimeDecay(
#     0.001,
#     decay_steps=1875*100,
#     decay_rate=5,
#     staircase=False
# )



rlrop = ReduceLROnPlateau(
    monitor = "val_accuracy",
    factor = 0.25,
    patience = 3,
    verbose = 1,
    min_lr = 0.5e-5
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       3584
#
#  batch_normalization_8 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_10 (Ba  (None, 8, 8, 512)         2048
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_8 (Dense)             (None, 1024)              8389632
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  batch_normalization_11 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 100)               25700
#
# =================================================================
# Total params: 13653476 (52.08 MB)
# Trainable params: 13650660 (52.07 MB)
# Non-trainable params: 2816 (11.00 KB)
# _________________________________________________________________

# %% [markdown]
# #Entrenamiento

# %%
mc = ModelCheckpoint(
    "best.weights.h5",
    monitor = "val_accuracy",
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
)

# %%
es = EarlyStopping(
    monitor = "val_accuracy",
    patience = 8,
    verbose = 1,
    restore_best_weights = True,
)

# %%
tb = TensorBoard(
    log_dir="logs",
)

# %%
history = model.fit(
#     x = X_train_flip,
#     y= Y_train_fine_flip,
    datagen.flow(X_train_final, Y_train_final, batch_size=64),
    batch_size=64,
    epochs=200,
    validation_data =(X_train_cv, y_train_cv),
    callbacks= [
        rlrop,
        es,
        mc,
        tb,
    ]
)
# Out:
# Epoch 1/200
# 703/704 [============================>.] - ETA: 0s - loss: 3.9719 - accuracy: 0.0973
# Epoch 1: val_accuracy improved from -inf to 0.16760, saving model to best.weights.h5
# 704/704 [==============================] - 47s 62ms/step - loss: 3.9711 - accuracy: 0.0974 - val_loss: 3.4283 - val_accuracy: 0.1676 - lr: 0.0010
# Epoch 2/200
# 704/704 [==============================] - ETA: 0s - loss: 3.2997 - accuracy: 0.2021
# Epoch 2: val_accuracy improved from 0.16760 to 0.18190, saving model to best.weights.h5
# 704/704 [==============================] - 42s 59ms/step - loss: 3.2997 - accuracy: 0.2021 - val_loss: 3.5561 - val_accuracy: 0.1819 - lr: 0.0010
# Epoch 3/200
# 703/704 [============================>.] - ETA: 0s - loss: 2.9014 - accuracy: 0.2730
# Epoch 3: val_accuracy improved from 0.18190 to 0.30300, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 2.9010 - accuracy: 0.2730 - val_loss: 2.7380 - val_accuracy: 0.3030 - lr: 0.0010
# Epoch 4/200
# 704/704 [==============================] - ETA: 0s - loss: 2.5700 - accuracy: 0.3371
# Epoch 4: val_accuracy improved from 0.30300 to 0.36880, saving model to best.weights.h5
# 704/704 [==============================] - 41s 58ms/step - loss: 2.5700 - accuracy: 0.3371 - val_loss: 2.4325 - val_accuracy: 0.3688 - lr: 0.0010
# Epoch 5/200
# 704/704 [==============================] - ETA: 0s - loss: 2.3061 - accuracy: 0.3943
# Epoch 5: val_accuracy improved from 0.36880 to 0.39600, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 2.3061 - accuracy: 0.3943 - val_loss: 2.3174 - val_accuracy: 0.3960 - lr: 0.0010
# Epoch 6/200
# 704/704 [==============================] - ETA: 0s - loss: 2.1301 - accuracy: 0.4311
# Epoch 6: val_accuracy improved from 0.39600 to 0.40210, saving model to best.weights.h5
# 704/704 [==============================] - 41s 59ms/step - loss: 2.1301 - accuracy: 0.4311 - val_loss: 2.4029 - val_accuracy: 0.4021 - lr: 0.0010
# Epoch 7/200
# 704/704 [==============================] - ETA: 0s - loss: 1.9345 - accuracy: 0.4778
# Epoch 7: val_accuracy improved from 0.40210 to 0.45470, saving model to best.weights.h5
# 704/704 [==============================] - 45s 64ms/step - loss: 1.9345 - accuracy: 0.4778 - val_loss: 2.0676 - val_accuracy: 0.4547 - lr: 0.0010
# Epoch 8/200
# 703/704 [============================>.] - ETA: 0s - loss: 1.7999 - accuracy: 0.5076
# Epoch 8: val_accuracy improved from 0.45470 to 0.48510, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 1.7998 - accuracy: 0.5075 - val_loss: 1.9649 - val_accuracy: 0.4851 - lr: 0.0010
# Epoch 9/200
# 703/704 [============================>.] - ETA: 0s - loss: 1.6741 - accuracy: 0.5392
# Epoch 9: val_accuracy improved from 0.48510 to 0.49210, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 1.6741 - accuracy: 0.5392 - val_loss: 1.9561 - val_accuracy: 0.4921 - lr: 0.0010
# Epoch 10/200
# 704/704 [==============================] - ETA: 0s - loss: 1.5637 - accuracy: 0.5662
# Epoch 10: val_accuracy did not improve from 0.49210
# 704/704 [==============================] - 42s 59ms/step - loss: 1.5637 - accuracy: 0.5662 - val_loss: 1.9613 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 11/200
# 704/704 [==============================] - ETA: 0s - loss: 1.4832 - accuracy: 0.5852
# Epoch 11: val_accuracy improved from 0.49210 to 0.49470, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 1.4832 - accuracy: 0.5852 - val_loss: 1.9488 - val_accuracy: 0.4947 - lr: 0.0010
# Epoch 12/200
# 704/704 [==============================] - ETA: 0s - loss: 1.3944 - accuracy: 0.6088
# Epoch 12: val_accuracy improved from 0.49470 to 0.52780, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 1.3944 - accuracy: 0.6088 - val_loss: 1.8051 - val_accuracy: 0.5278 - lr: 0.0010
# Epoch 13/200
# 704/704 [==============================] - ETA: 0s - loss: 1.3306 - accuracy: 0.6230
# Epoch 13: val_accuracy did not improve from 0.52780
# 704/704 [==============================] - 41s 58ms/step - loss: 1.3306 - accuracy: 0.6230 - val_loss: 2.1095 - val_accuracy: 0.4847 - lr: 0.0010
# Epoch 14/200
# 704/704 [==============================] - ETA: 0s - loss: 1.2663 - accuracy: 0.6375
# Epoch 14: val_accuracy improved from 0.52780 to 0.53070, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 1.2663 - accuracy: 0.6375 - val_loss: 1.8288 - val_accuracy: 0.5307 - lr: 0.0010
# Epoch 15/200
# 704/704 [==============================] - ETA: 0s - loss: 1.1909 - accuracy: 0.6586
# Epoch 15: val_accuracy improved from 0.53070 to 0.55730, saving model to best.weights.h5
# 704/704 [==============================] - 45s 64ms/step - loss: 1.1909 - accuracy: 0.6586 - val_loss: 1.7020 - val_accuracy: 0.5573 - lr: 0.0010
# Epoch 16/200
# 704/704 [==============================] - ETA: 0s - loss: 1.1488 - accuracy: 0.6682
# Epoch 16: val_accuracy did not improve from 0.55730
# 704/704 [==============================] - 41s 58ms/step - loss: 1.1488 - accuracy: 0.6682 - val_loss: 1.8718 - val_accuracy: 0.5383 - lr: 0.0010
# Epoch 17/200
# 704/704 [==============================] - ETA: 0s - loss: 1.1089 - accuracy: 0.6773
# Epoch 17: val_accuracy improved from 0.55730 to 0.56580, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 1.1089 - accuracy: 0.6773 - val_loss: 1.6913 - val_accuracy: 0.5658 - lr: 0.0010
# Epoch 18/200
# 704/704 [==============================] - ETA: 0s - loss: 1.0522 - accuracy: 0.6933
# Epoch 18: val_accuracy did not improve from 0.56580
# 704/704 [==============================] - 41s 58ms/step - loss: 1.0522 - accuracy: 0.6933 - val_loss: 1.8264 - val_accuracy: 0.5395 - lr: 0.0010
# Epoch 19/200
# 704/704 [==============================] - ETA: 0s - loss: 1.0718 - accuracy: 0.6876
# Epoch 19: val_accuracy did not improve from 0.56580
# 704/704 [==============================] - 40s 57ms/step - loss: 1.0718 - accuracy: 0.6876 - val_loss: 1.7441 - val_accuracy: 0.5636 - lr: 0.0010
# Epoch 20/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.9833 - accuracy: 0.7113
# Epoch 20: val_accuracy improved from 0.56580 to 0.57520, saving model to best.weights.h5
# 704/704 [==============================] - 46s 66ms/step - loss: 0.9835 - accuracy: 0.7112 - val_loss: 1.6648 - val_accuracy: 0.5752 - lr: 0.0010
# Epoch 21/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.9446 - accuracy: 0.7209
# Epoch 21: val_accuracy did not improve from 0.57520
# 704/704 [==============================] - 42s 60ms/step - loss: 0.9451 - accuracy: 0.7208 - val_loss: 1.7042 - val_accuracy: 0.5661 - lr: 0.0010
# Epoch 22/200
# 704/704 [==============================] - ETA: 0s - loss: 0.9215 - accuracy: 0.7298
# Epoch 22: val_accuracy did not improve from 0.57520
# 704/704 [==============================] - 40s 57ms/step - loss: 0.9215 - accuracy: 0.7298 - val_loss: 1.8112 - val_accuracy: 0.5510 - lr: 0.0010
# Epoch 23/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.9087 - accuracy: 0.7318
# Epoch 23: val_accuracy improved from 0.57520 to 0.58560, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 0.9090 - accuracy: 0.7317 - val_loss: 1.6480 - val_accuracy: 0.5856 - lr: 0.0010
# Epoch 24/200
# 704/704 [==============================] - ETA: 0s - loss: 0.8723 - accuracy: 0.7399
# Epoch 24: val_accuracy did not improve from 0.58560
# 704/704 [==============================] - 41s 59ms/step - loss: 0.8723 - accuracy: 0.7399 - val_loss: 1.6942 - val_accuracy: 0.5823 - lr: 0.0010
# Epoch 25/200
# 704/704 [==============================] - ETA: 0s - loss: 0.8548 - accuracy: 0.7436
# Epoch 25: val_accuracy improved from 0.58560 to 0.58900, saving model to best.weights.h5
# 704/704 [==============================] - 46s 66ms/step - loss: 0.8548 - accuracy: 0.7436 - val_loss: 1.6917 - val_accuracy: 0.5890 - lr: 0.0010
# Epoch 26/200
# 704/704 [==============================] - ETA: 0s - loss: 0.8327 - accuracy: 0.7520
# Epoch 26: val_accuracy did not improve from 0.58900
# 704/704 [==============================] - 41s 58ms/step - loss: 0.8327 - accuracy: 0.7520 - val_loss: 1.6867 - val_accuracy: 0.5872 - lr: 0.0010
# Epoch 27/200
# 704/704 [==============================] - ETA: 0s - loss: 0.7957 - accuracy: 0.7623
# Epoch 27: val_accuracy improved from 0.58900 to 0.59120, saving model to best.weights.h5
# 704/704 [==============================] - 49s 69ms/step - loss: 0.7957 - accuracy: 0.7623 - val_loss: 1.6602 - val_accuracy: 0.5912 - lr: 0.0010
# Epoch 28/200
# 704/704 [==============================] - ETA: 0s - loss: 0.8061 - accuracy: 0.7586
# Epoch 28: val_accuracy did not improve from 0.59120
# 704/704 [==============================] - 41s 58ms/step - loss: 0.8061 - accuracy: 0.7586 - val_loss: 1.7259 - val_accuracy: 0.5889 - lr: 0.0010
# Epoch 29/200
# 704/704 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.7742
# Epoch 29: val_accuracy did not improve from 0.59120
# 704/704 [==============================] - 42s 59ms/step - loss: 0.7542 - accuracy: 0.7742 - val_loss: 1.7322 - val_accuracy: 0.5809 - lr: 0.0010
# Epoch 30/200
# 704/704 [==============================] - ETA: 0s - loss: 0.7560 - accuracy: 0.7722
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 30: val_accuracy did not improve from 0.59120
# 704/704 [==============================] - 42s 59ms/step - loss: 0.7560 - accuracy: 0.7722 - val_loss: 1.7257 - val_accuracy: 0.5850 - lr: 0.0010
# Epoch 31/200
# 704/704 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.8424
# Epoch 31: val_accuracy improved from 0.59120 to 0.62830, saving model to best.weights.h5
# 704/704 [==============================] - 43s 61ms/step - loss: 0.5185 - accuracy: 0.8424 - val_loss: 1.5787 - val_accuracy: 0.6283 - lr: 2.5000e-04
# Epoch 32/200
# 704/704 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8688
# Epoch 32: val_accuracy improved from 0.62830 to 0.63100, saving model to best.weights.h5
# 704/704 [==============================] - 49s 69ms/step - loss: 0.4279 - accuracy: 0.8688 - val_loss: 1.5993 - val_accuracy: 0.6310 - lr: 2.5000e-04
# Epoch 33/200
# 704/704 [==============================] - ETA: 0s - loss: 0.3625 - accuracy: 0.8879
# Epoch 33: val_accuracy improved from 0.63100 to 0.63610, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 0.3625 - accuracy: 0.8879 - val_loss: 1.6255 - val_accuracy: 0.6361 - lr: 2.5000e-04
# Epoch 34/200
# 704/704 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8968
# Epoch 34: val_accuracy did not improve from 0.63610
# 704/704 [==============================] - 41s 58ms/step - loss: 0.3300 - accuracy: 0.8968 - val_loss: 1.6673 - val_accuracy: 0.6304 - lr: 2.5000e-04
# Epoch 35/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.3034 - accuracy: 0.9054
# Epoch 35: val_accuracy did not improve from 0.63610
# 704/704 [==============================] - 42s 59ms/step - loss: 0.3035 - accuracy: 0.9053 - val_loss: 1.7479 - val_accuracy: 0.6306 - lr: 2.5000e-04
# Epoch 36/200
# 704/704 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.9129
# Epoch 36: val_accuracy improved from 0.63610 to 0.63740, saving model to best.weights.h5
# 704/704 [==============================] - 49s 69ms/step - loss: 0.2804 - accuracy: 0.9129 - val_loss: 1.7056 - val_accuracy: 0.6374 - lr: 2.5000e-04
# Epoch 37/200
# 704/704 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9200
# Epoch 37: val_accuracy did not improve from 0.63740
# 704/704 [==============================] - 41s 58ms/step - loss: 0.2563 - accuracy: 0.9200 - val_loss: 1.8333 - val_accuracy: 0.6236 - lr: 2.5000e-04
# Epoch 38/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.2402 - accuracy: 0.9243
# Epoch 38: val_accuracy did not improve from 0.63740
# 704/704 [==============================] - 41s 58ms/step - loss: 0.2402 - accuracy: 0.9243 - val_loss: 1.7894 - val_accuracy: 0.6321 - lr: 2.5000e-04
# Epoch 39/200
# 704/704 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9287
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 39: val_accuracy did not improve from 0.63740
# 704/704 [==============================] - 41s 58ms/step - loss: 0.2240 - accuracy: 0.9287 - val_loss: 1.8673 - val_accuracy: 0.6290 - lr: 2.5000e-04
# Epoch 40/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9384
# Epoch 40: val_accuracy did not improve from 0.63740
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1979 - accuracy: 0.9384 - val_loss: 1.8174 - val_accuracy: 0.6357 - lr: 6.2500e-05
# Epoch 41/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9436
# Epoch 41: val_accuracy improved from 0.63740 to 0.63820, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 0.1793 - accuracy: 0.9436 - val_loss: 1.7972 - val_accuracy: 0.6382 - lr: 6.2500e-05
# Epoch 42/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9467
# Epoch 42: val_accuracy improved from 0.63820 to 0.63870, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 0.1666 - accuracy: 0.9467 - val_loss: 1.8318 - val_accuracy: 0.6387 - lr: 6.2500e-05
# Epoch 43/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9505
# Epoch 43: val_accuracy improved from 0.63870 to 0.63890, saving model to best.weights.h5
# 704/704 [==============================] - 44s 63ms/step - loss: 0.1591 - accuracy: 0.9505 - val_loss: 1.8284 - val_accuracy: 0.6389 - lr: 6.2500e-05
# Epoch 44/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9522
# Epoch 44: val_accuracy improved from 0.63890 to 0.63910, saving model to best.weights.h5
# 704/704 [==============================] - 42s 60ms/step - loss: 0.1505 - accuracy: 0.9522 - val_loss: 1.8341 - val_accuracy: 0.6391 - lr: 6.2500e-05
# Epoch 45/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 0.9547
# Epoch 45: val_accuracy did not improve from 0.63910
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1480 - accuracy: 0.9547 - val_loss: 1.8422 - val_accuracy: 0.6379 - lr: 6.2500e-05
# Epoch 46/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9561
# Epoch 46: val_accuracy improved from 0.63910 to 0.64050, saving model to best.weights.h5
# 704/704 [==============================] - 45s 65ms/step - loss: 0.1420 - accuracy: 0.9561 - val_loss: 1.8430 - val_accuracy: 0.6405 - lr: 6.2500e-05
# Epoch 47/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9576
# Epoch 47: val_accuracy did not improve from 0.64050
# 704/704 [==============================] - 40s 57ms/step - loss: 0.1380 - accuracy: 0.9576 - val_loss: 1.8702 - val_accuracy: 0.6405 - lr: 6.2500e-05
# Epoch 48/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9588
# Epoch 48: val_accuracy did not improve from 0.64050
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1322 - accuracy: 0.9588 - val_loss: 1.8903 - val_accuracy: 0.6384 - lr: 6.2500e-05
# Epoch 49/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9597
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 49: val_accuracy did not improve from 0.64050
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1274 - accuracy: 0.9597 - val_loss: 1.8808 - val_accuracy: 0.6392 - lr: 6.2500e-05
# Epoch 50/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9624
# Epoch 50: val_accuracy did not improve from 0.64050
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1198 - accuracy: 0.9624 - val_loss: 1.8767 - val_accuracy: 0.6402 - lr: 1.5625e-05
# Epoch 51/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9620
# Epoch 51: val_accuracy did not improve from 0.64050
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1214 - accuracy: 0.9620 - val_loss: 1.8928 - val_accuracy: 0.6398 - lr: 1.5625e-05
# Epoch 52/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9618
# Epoch 52: val_accuracy improved from 0.64050 to 0.64120, saving model to best.weights.h5
# 704/704 [==============================] - 47s 67ms/step - loss: 0.1183 - accuracy: 0.9618 - val_loss: 1.8886 - val_accuracy: 0.6412 - lr: 1.5625e-05
# Epoch 53/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9632
# Epoch 53: val_accuracy improved from 0.64120 to 0.64270, saving model to best.weights.h5
# 704/704 [==============================] - 49s 70ms/step - loss: 0.1162 - accuracy: 0.9632 - val_loss: 1.8876 - val_accuracy: 0.6427 - lr: 1.5625e-05
# Epoch 54/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9659
# Epoch 54: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1097 - accuracy: 0.9659 - val_loss: 1.8923 - val_accuracy: 0.6404 - lr: 1.5625e-05
# Epoch 55/200
# 703/704 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.9652
# Epoch 55: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 41s 59ms/step - loss: 0.1119 - accuracy: 0.9652 - val_loss: 1.8959 - val_accuracy: 0.6410 - lr: 1.5625e-05
# Epoch 56/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9664
# Epoch 56: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 56: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1088 - accuracy: 0.9664 - val_loss: 1.8992 - val_accuracy: 0.6422 - lr: 1.5625e-05
# Epoch 57/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9670
# Epoch 57: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1064 - accuracy: 0.9670 - val_loss: 1.9019 - val_accuracy: 0.6420 - lr: 5.0000e-06
# Epoch 58/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9662
# Epoch 58: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1070 - accuracy: 0.9662 - val_loss: 1.9009 - val_accuracy: 0.6419 - lr: 5.0000e-06
# Epoch 59/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9663
# Epoch 59: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 41s 58ms/step - loss: 0.1102 - accuracy: 0.9663 - val_loss: 1.9052 - val_accuracy: 0.6414 - lr: 5.0000e-06
# Epoch 60/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9663
# Epoch 60: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1096 - accuracy: 0.9663 - val_loss: 1.9033 - val_accuracy: 0.6421 - lr: 5.0000e-06
# Epoch 61/200
# 704/704 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9678Restoring model weights from the end of the best epoch: 53.
#
# Epoch 61: val_accuracy did not improve from 0.64270
# 704/704 [==============================] - 42s 59ms/step - loss: 0.1038 - accuracy: 0.9678 - val_loss: 1.9073 - val_accuracy: 0.6421 - lr: 5.0000e-06
# Epoch 61: early stopping

# %% [markdown]
# #Resultados

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])

# %%
predictions = model.predict(x_test)

#test_accuracy_prom=sum(np.array(predictions)==np.array(x_test[\"target\"]))/len(twenty_test[\"target\"])*100\n))
# Out:
# 313/313 [==============================] - 3s 8ms/step

# %%
predictions = predictions.argmax(axis=1)

# %%
predictions
# Out:
# array([68, 33, 30, ..., 51, 42, 70])

# %%
df = pd.DataFrame(predictions, columns=["Label"])

# %%
df.index.name = "Id"

# %%
df.head()
# Out:
#     Label
# Id
# 0      68
# 1      33
# 2      30
# 3      91
# 4      71

# %%
df.to_csv("submission.csv")
